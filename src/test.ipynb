# %%
print("Hello, my friends!")
# Out:
# Hello, my friends!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
away_dog_wins = pd.read_csv("../groupscores/awaydogswin.csv")
away_dog_wins
# Out:
#      away_team_id  wins  games  dogscore
# 0            1773     5     37  0.135135
# 1            2033     7     53  0.132075
# 2            4049     1     16  0.062500
# 3            4064     1     11  0.090909
# 4            4087    12     61  0.196721
# ..            ...   ...    ...       ...
# 249        108893     1     19  0.052632
# 250        158085     3     31  0.096774
# 251        188163     5     17  0.294118
# 252        208931     1     16  0.062500
# 253        274581     5     25  0.200000
#
# [254 rows x 4 columns]

# %%
home_dog_wins = pd.read_csv("../groupscores/homedogswin.csv")
home_dog_wins
# Out:
#      home_team_id  wins  games  dogscore
# 0            1773     3     11  0.272727
# 1            2033     1     24  0.041667
# 2            4049     2      8  0.250000
# 3            4087     2     14  0.142857
# 4            6269     2      6  0.333333
# ..            ...   ...    ...       ...
# 184         10281     4     12  0.333333
# 185        108893     1     13  0.076923
# 186        158085     2     12  0.166667
# 187        208931     1      7  0.142857
# 188        274581     3      7  0.428571
#
# [189 rows x 4 columns]

# %%
plt.figure(figsize=(6, 6))
plt.subplot(2, 1, 1)
home_dog_scores = np.array(home_dog_wins['dogscore'])
home_dog_scores.sort()

plt.hist(home_dog_scores, bins = 30, edgecolor="black")
plt.title("Home Dog wins")
plt.ylabel("counts")
plt.xlabel("dog score")
away_dog_scores = np.array(away_dog_wins['dogscore'])
away_dog_scores.sort()
plt.subplot(2, 1, 2)
plt.hist(away_dog_scores, bins = 30, edgecolor="black")
plt.title("away dog wins")
plt.xlabel("dog score")
plt.ylabel("counts")
plt.tight_layout()
plt.show()

# %%
# Out:
#      Unnamed: 0  away_team_id  wins  games  dogscore
# 0             1          1773     5     28  0.178571
# 1             2          2033     5     32  0.156250
# 2             3          4087    10     52  0.192308
# 3             4          4170     3     12  0.250000
# 4             5          6269     2     13  0.153846
# ..          ...           ...   ...    ...       ...
# 236         237        108893     1     15  0.066667
# 237         238        158085     1     25  0.040000
# 238         239        188163     2      7  0.285714
# 239         240        208931     1     12  0.083333
# 240         241        274581     5     22  0.227273
#
# [241 rows x 5 columns]
